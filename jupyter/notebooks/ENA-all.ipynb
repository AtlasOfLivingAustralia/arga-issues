# %% [markdown]
# # ENA Genome sequence data ingestion script
#
# See https://github.com/ARGA-Genomes/arga-data/issues/4 for details

# %%
import pandas as pd

# df = pd.read_table("https://www.ebi.ac.uk/ena/portal/api/search?result=assembly&fields=all&limit=0&format=tsv")
df = pd.read_table("../data/ena_assembly_all_fields.tsv", dtype='object', parse_dates=['last_updated']) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1362659 entries, 0 to 1362658
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   accession                   1362659 non-null  object
#  1   study_accession             1323342 non-null  object
#  2   sample_accession            1320714 non-null  object
#  3   secondary_sample_accession  1037393 non-null  object
#  4   assembly_name               1362444 non-null  object
#  5   assembly_title              1362658 non-null  object
#  6   study_name                  1067333 non-null  object
#  7   study_title                 1323205 non-null  object
#  8   study_description           1318363 non-null  object
#  9   tax_id                      1362659 non-null  object
#  10  scientific_name             1362659 non-null  object
#  11  strain                      1038663 non-null  object
# ...

# %%
# Look at 10 records...
df.head(10)
# Out:
#        accession study_accession sample_accession secondary_sample_accession  \
# 0  GCA_000001215      PRJNA13812     SAMN02803731                        NaN
# 1  GCA_000001215      PRJNA13812     SAMN02803731                        NaN
# 2  GCA_000001215      PRJNA13812     SAMN02803731                        NaN
# 3  GCA_000001405      PRJNA31257              NaN                        NaN
# 4  GCA_000001405      PRJNA31257              NaN                        NaN
# 5  GCA_000001405      PRJNA31257              NaN                        NaN
# 6  GCA_000001405      PRJNA31257              NaN                        NaN
# 7  GCA_000001405      PRJNA31257              NaN                        NaN
# 8  GCA_000001405      PRJNA31257              NaN                        NaN
# 9  GCA_000001405      PRJNA31257              NaN                        NaN
#
#             assembly_name                                     assembly_title  \
# ...
