# %% [markdown]
# ## Notebook for downloading and importing AusTraits data into specieslist lists
#
# __Aim of script__: to extract a list of taxa with trait data for a single "trait" and upload the compiled CSV file to an existing species list (replacing rows with updated data).
#
# AusTraits Swagger docs: [`http://traitdata.austraits.cloud.edu.au/__docs__/#`](http://http://traitdata.austraits.cloud.edu.au/__docs__/#)
#
# `download_trait_data` service URL: `http://traitdata.austraits.cloud.edu.au/download-trait-data`
#
# Example POST:
# `curl -X POST "http://traitdata.austraits.cloud.edu.au/download-trait-data" -H "accept: */*" -H "Content-Type: application/json" -d "{\"taxa\":[],\"traits\":[\"post_fire_recruitment\"]}"`
#
# POST body example:
# ```json
# {
#   "traits": [
#     "post_fire_recruitment"
#   ]
# }
# ```
#
# AusTraits trait definitions: https://traitecoevo.github.io/austraits.build/articles/trait_definitions.html#fire_response
#
# ALA list tool Swagger docs: https://docs.ala.org.au/openapi/index.html?urls.primaryName=specieslist
#
# POST to https://docs.ala.org.au/openapi/index.html?urls.primaryName=specieslist#/Lists/Add%20or%20replace%20a%20species%20list
#
# **NOTE**: posting data to lists.ala.org.au requires a `.env` file at the repository root, that will contain sensitive data.
# Use the `.env.template` as a starting point and do NOT add the `.env` to git (`.gitignore` will prevent this).
#
# ### TODO fixes and improvements
#
# - [ ] Convert to vanilla Python script for easier automating and running via Airflow, etc.
# - [ ] Use command-line arg for `trait_name` variable and type-check input via Enum
# - [x] Fix duplicate values after processing: `fire_killed|fire_killed`, `resprouts|resprouts`, `resprouts|resprouts|resprouts`
# - [x] Fix values with same "items" with different order - combine to single "set", e,g, `fire_killed|resprouts` and `resprouts|fire_killed`. Put in `Set` first?
# - [x] Fix remove values of `unknown` (convert to empty string)
# - [-] Move all URLs into config - so `test` vs `prod` URLs can be specified
# - [-] Move references to list DRs IDs into config
# - [x] Move Oauth/JWT code into helper script in `code` directory
# - [x] Add code to regenerate the `access_token` using the `refresh_token`

# %%
import requests
import pandas as pd
import io
from enum import Enum
import decouple

config = decouple.AutoConfig(' ') # this is a hack for Jupyter due to running in a sandbox

# Lists-test DRs 
# TODO: move in ENVs similar to `ACCESS_TOKEN`?

Traits = Enum("Traits",
    [
        ("fire_response", config('DR_FIRE_RESPONSE', default="dr18689")),
        ("post_fire_recruitment", config('DR_POST_FIRE_RECRUITMENT', default="dr18693")),
        ("photosynthetic_pathway", config('DR_PHOTOSYNTHETIC_PATHWAY', default="dr18707")),
    ]
)

# this_trait = Traits['post_fire_recruitment'] # TODO: handle via args
this_trait = Traits['fire_response'] # TODO: handle via args
trait_name = this_trait.name # "fire_response" | "post_fire_recruitment"
trait_dr_id = this_trait.value

austraits_base_url = config('AUSTRAITS_BASE_URL', default="http://traitdata.austraits.cloud.edu.au")
url = f"{austraits_base_url}/download-trait-data"
json_body = { "traits": [ trait_name ] }
print("url", url, json_body)
exit
response = requests.post(url, json = json_body)
df = pd.read_csv(io.StringIO(response.text), sep=",", dtype=str, keep_default_na=False)
total_rows = len(df.index)
print("Total rows =",total_rows)
df.info()
# Out:
# url http://traitdata.austraits.cloud.edu.au/download-trait-data {'traits': ['fire_response']}
# Total rows = 19500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19500 entries, 0 to 19499
# Data columns (total 53 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   dataset_id                        19500 non-null  object
#  1   taxon_name                        19500 non-null  object
#  2   observation_id                    19500 non-null  object
#  3   trait_name                        19500 non-null  object
#  4   trait_value                       19500 non-null  object
#  5   unit                              19500 non-null  object
#  6   entity_type                       19500 non-null  object
#  7   value_type                        19500 non-null  object
#  8   basis_of_value                    19500 non-null  object
#  9   replicates                        19500 non-null  object
#  10  basis_of_record                   19500 non-null  object
#  11  life_stage                        19500 non-null  object
#  12  population_id                     19500 non-null  object
#  13  individual_id                     19500 non-null  object
#  14  temporal_id                       19500 non-null  object
#  15  source_id                         19500 non-null  object
#  16  location_id                       19500 non-null  object
#  17  entity_context_id                 19500 non-null  object
#  18  plot_id                           19500 non-null  object
#  19  treatment_id                      19500 non-null  object
#  20  collection_date                   19500 non-null  object
#  21  measurement_remarks               19500 non-null  object
#  22  method_id                         19500 non-null  object
#  23  original_name                     19500 non-null  object
#  24  context                           19500 non-null  object
#  25  latitude (deg)                    19500 non-null  object
#  26  longitude (deg)                   19500 non-null  object
#  27  location                          19500 non-null  object
#  28  methods                           19500 non-null  object
#  29  dataset_description               19500 non-null  object
#  30  sampling_strategy                 19500 non-null  object
#  31  source_primary_key                19500 non-null  object
#  32  source_primary_citation           19500 non-null  object
#  33  source_secondary_key              19500 non-null  object
#  34  source_secondary_citation         19500 non-null  object
#  35  source_original_dataset_key       19500 non-null  object
#  36  source_original_dataset_citation  19500 non-null  object
#  37  data_collectors                   19500 non-null  object
#  38  assistants                        19500 non-null  object
#  39  austraits_curators                19500 non-null  object
#  40  taxonNameValidation               19500 non-null  object
#  41  taxon_rank                        19500 non-null  object
#  42  trinomial                         19500 non-null  object
#  43  binomial                          19500 non-null  object
#  44  genus                             19500 non-null  object
#  45  family                            19500 non-null  object
#  46  taxon_distribution                19500 non-null  object
#  47  establishment_means               19500 non-null  object
#  48  taxonomic_status                  19500 non-null  object
#  49  scientific_name                   19500 non-null  object
#  50  scientific_name_authorship        19500 non-null  object
#  51  taxon_id                          19500 non-null  object
#  52  scientific_name_id                19500 non-null  object
# dtypes: object(53)
# memory usage: 7.9+ MB

# %% [markdown]
# Sort the table on taxon_name, so we can see the duplicate entries on `taxon_name`

# %%
df.sort_values(by=['taxon_name'], ascending=True, inplace=True)
df.head(20)
# Out:
#              dataset_id                            taxon_name observation_id  \
# 1667        Clarke_2015                 Abelmoschus ficulneus           0001
# 1668        Clarke_2015                 Abelmoschus moschatus           0002
# 13254        White_2020                  Abrodictyum caudatum           1747
# 16314        White_2020                  Abrodictyum caudatum           4818
# 11515        White_2020                           Abrotanella           0005
# 5019   Kirkpatrick_2020              Abrotanella forsteroides            001
# 11514        White_2020                  Abrotanella nivigena           0004
# 10752      Schmidt_2003                     Abrus precatorius           0005
# 11530        White_2020                              Abutilon           0020
# 11516        White_2020                 Abutilon calliphyllum           0006
# 11519        White_2020                      Abutilon fraseri           0009
# 11517        White_2020  Abutilon fraseri subsp. diplotrichum           0007
# 11518        White_2020       Abutilon fraseri subsp. fraseri           0008
# 1669        Clarke_2015                 Abutilon grandifolium           0003
# 11520        White_2020                   Abutilon halophilum           0010
# 1670        Clarke_2015                       Abutilon hannii           0004
# 11521        White_2020                 Abutilon leucopetalum           0011
# 11522        White_2020                  Abutilon malvifolium           0012
# 11523        White_2020                  Abutilon malvifolium           0013
# 11524        White_2020                    Abutilon otocarpum           0014
#
#           trait_name  trait_value unit entity_type value_type basis_of_value  \
# 1667   fire_response  fire_killed       population       mode   expert_score
# 1668   fire_response    resprouts       population       mode   expert_score
# 13254  fire_response  fire_killed          species       mode   expert_score
# 16314  fire_response  fire_killed          species       mode   expert_score
# 11515  fire_response    resprouts          species       mode   expert_score
# 5019   fire_response    resprouts          species       mode   expert_score
# 11514  fire_response    resprouts          species       mode   expert_score
# 10752  fire_response    resprouts          species       mode   expert_score
# 11530  fire_response  fire_killed          species       mode   expert_score
# 11516  fire_response  fire_killed          species       mode   expert_score
# 11519  fire_response  fire_killed          species       mode   expert_score
# 11517  fire_response  fire_killed          species       mode   expert_score
# 11518  fire_response  fire_killed          species       mode   expert_score
# 1669   fire_response  fire_killed       population       mode   expert_score
# 11520  fire_response  fire_killed          species       mode   expert_score
# 1670   fire_response  fire_killed       population       mode   expert_score
# 11521  fire_response  fire_killed          species       mode   expert_score
# 11522  fire_response  fire_killed          species       mode   expert_score
# 11523  fire_response  fire_killed          species       mode   expert_score
# 11524  fire_response  fire_killed          species       mode   expert_score
#
#       replicates  ...                  binomial        genus  \
# 1667              ...     Abelmoschus ficulneus  Abelmoschus
# 1668              ...     Abelmoschus moschatus  Abelmoschus
# 13254             ...      Abrodictyum caudatum  Abrodictyum
# 16314             ...      Abrodictyum caudatum  Abrodictyum
# 11515             ...                            Abrotanella
# 5019              ...  Abrotanella forsteroides  Abrotanella
# 11514             ...      Abrotanella nivigena  Abrotanella
# 10752             ...         Abrus precatorius        Abrus
# 11530             ...                               Abutilon
# 11516             ...     Abutilon calliphyllum     Abutilon
# 11519             ...          Abutilon fraseri     Abutilon
# 11517             ...          Abutilon fraseri     Abutilon
# 11518             ...          Abutilon fraseri     Abutilon
# 1669              ...     Abutilon grandifolium     Abutilon
# 11520             ...       Abutilon halophilum     Abutilon
# 1670              ...           Abutilon hannii     Abutilon
# 11521             ...     Abutilon leucopetalum     Abutilon
# 11522             ...      Abutilon malvifolium     Abutilon
# 11523             ...      Abutilon malvifolium     Abutilon
# 11524             ...        Abutilon otocarpum     Abutilon
#
#                  family                                 taxon_distribution  \
# 1667          Malvaceae                                        WA, NT, Qld
# 1668          Malvaceae                     WA, NT, Qld, NSW (naturalised)
# 13254  Hymenophyllaceae                                      Qld, NSW, Vic
# 16314  Hymenophyllaceae                                      Qld, NSW, Vic
# 11515        Asteraceae
# 5019         Asteraceae                                                Tas
# 11514        Asteraceae                                           NSW, Vic
# 10752          Fabaceae                                   WA, NT, Qld, NSW
# 11530         Malvaceae
# 11516         Malvaceae                                                Qld
# 11519         Malvaceae                          WA, NT, SA, Qld, NSW, Vic
# 11517         Malvaceae                                       SA, Qld, Vic
# 11518         Malvaceae                               WA, NT, SA, Qld, Vic
# 1669          Malvaceae  WA (doubtfully naturalised), Qld (naturalised)...
# 11520         Malvaceae                               WA, NT, SA, Qld, NSW
# 1670          Malvaceae                                        WA, NT, Qld
# 11521         Malvaceae                               WA, NT, SA, Qld, NSW
# 11522         Malvaceae                          WA, NT, SA, Qld, NSW, Vic
# 11523         Malvaceae                          WA, NT, SA, Qld, NSW, Vic
# 11524         Malvaceae                          WA, NT, SA, Qld, NSW, Vic
#
#           establishment_means taxonomic_status  \
# 1667                   native         accepted
# 1668   native and naturalised         accepted
# 13254                  native         accepted
# 16314                  native         accepted
# 11515                                 accepted
# 5019                   native         accepted
# 11514                  native         accepted
# 10752                  native         accepted
# 11530                                 accepted
# 11516                  native         accepted
# 11519                  native         accepted
# 11517                  native         accepted
# 11518                  native         accepted
# 1669              naturalised         accepted
# 11520                  native         accepted
# 1670                   native         accepted
# 11521                  native         accepted
# 11522                  native         accepted
# 11523                  native         accepted
# 11524                  native         accepted
#
#                                          scientific_name  \
# 1667                    Abelmoschus ficulneus (L.) Wight
# 1668                        Abelmoschus moschatus Medik.
# 13254   Abrodictyum caudatum (Brack.) Ebihara & K.Iwats.
# 16314   Abrodictyum caudatum (Brack.) Ebihara & K.Iwats.
# 11515                                  Abrotanella Cass.
# 5019           Abrotanella forsteroides (Hook.f.) Benth.
# 11514           Abrotanella nivigena (F.Muell.) F.Muell.
# 10752                               Abrus precatorius L.
# 11530                                     Abutilon Mill.
# 11516                        Abutilon calliphyllum Domin
# 11519                     Abutilon fraseri (Hook.) Walp.
# 11517  Abutilon fraseri subsp. diplotrichum (F.Muell....
# 11518      Abutilon fraseri (Hook.) Walp. subsp. fraseri
# 1669                Abutilon grandifolium (Willd.) Sweet
# 11520           Abutilon halophilum F.Muell. ex Schltdl.
# 1670                            Abutilon hannii Baker f.
# 11521  Abutilon leucopetalum (F.Muell.) F.Muell. ex B...
# 11522            Abutilon malvifolium (Benth.) J.M.Black
# 11523            Abutilon malvifolium (Benth.) J.M.Black
# 11524                        Abutilon otocarpum F.Muell.
#
#               scientific_name_authorship  \
# 1667                          (L.) Wight
# 1668                              Medik.
# 13254        (Brack.) Ebihara & K.Iwats.
# 16314        (Brack.) Ebihara & K.Iwats.
# 11515                              Cass.
# 5019                    (Hook.f.) Benth.
# 11514                (F.Muell.) F.Muell.
# 10752                                 L.
# 11530                              Mill.
# 11516                              Domin
# 11519                      (Hook.) Walp.
# 11517  (F.Muell. ex Schltdl.) R.M.Barker
# 11518
# 1669                      (Willd.) Sweet
# 11520               F.Muell. ex Schltdl.
# 1670                            Baker f.
# 11521      (F.Muell.) F.Muell. ex Benth.
# 11522                 (Benth.) J.M.Black
# 11523                 (Benth.) J.M.Black
# 11524                           F.Muell.
#
#                                                 taxon_id  \
# 1667    https://id.biodiversity.org.au/node/apni/2897916
# 1668    https://id.biodiversity.org.au/node/apni/2900572
# 13254   https://id.biodiversity.org.au/node/apni/7402200
# 16314   https://id.biodiversity.org.au/node/apni/7402200
# 11515  https://id.biodiversity.org.au/taxon/apni/5126...
# 5019    https://id.biodiversity.org.au/node/apni/2901344
# 11514   https://id.biodiversity.org.au/node/apni/2900512
# 10752   https://id.biodiversity.org.au/node/apni/2919311
# 11530  https://id.biodiversity.org.au/taxon/apni/5143...
# 11516   https://id.biodiversity.org.au/node/apni/3835441
# 11519  https://id.biodiversity.org.au/taxon/apni/5143...
# 11517  https://id.biodiversity.org.au/taxon/apni/5143...
# 11518   https://id.biodiversity.org.au/node/apni/2902433
# 1669    https://id.biodiversity.org.au/node/apni/2921307
# 11520   https://id.biodiversity.org.au/node/apni/3470889
# 1670    https://id.biodiversity.org.au/node/apni/2887138
# 11521   https://id.biodiversity.org.au/node/apni/2911736
# 11522   https://id.biodiversity.org.au/node/apni/2887438
# 11523   https://id.biodiversity.org.au/node/apni/2887438
# 11524  https://id.biodiversity.org.au/taxon/apni/5143...
#
#                                     scientific_name_id
# 1667    https://id.biodiversity.org.au/name/apni/55929
# 1668    https://id.biodiversity.org.au/name/apni/55953
# 13254  https://id.biodiversity.org.au/name/apni/241954
# 16314  https://id.biodiversity.org.au/name/apni/241954
# 11515   https://id.biodiversity.org.au/name/apni/56103
# 5019    https://id.biodiversity.org.au/name/apni/56111
# 11514   https://id.biodiversity.org.au/name/apni/56120
# 10752   https://id.biodiversity.org.au/name/apni/56149
# 11530   https://id.biodiversity.org.au/name/apni/56205
# 11516   https://id.biodiversity.org.au/name/apni/56304
# 11519   https://id.biodiversity.org.au/name/apni/56365
# 11517  https://id.biodiversity.org.au/name/apni/171075
# 11518  https://id.biodiversity.org.au/name/apni/222416
# 1669    https://id.biodiversity.org.au/name/apni/56428
# 11520   https://id.biodiversity.org.au/name/apni/56459
# 1670    https://id.biodiversity.org.au/name/apni/56470
# 11521   https://id.biodiversity.org.au/name/apni/56564
# 11522   https://id.biodiversity.org.au/name/apni/56602
# 11523   https://id.biodiversity.org.au/name/apni/56602
# 11524   https://id.biodiversity.org.au/name/apni/56708
#
# [20 rows x 53 columns]

# %%
print(df[df['taxon_name'].str.contains('Panicum')])
# Out:
#          dataset_id                                  taxon_name  \
# 16891    White_2020                                     Panicum
# 16875    White_2020                              Panicum buncei
# 16879    White_2020                        Panicum decompositum
# 9760    NSWFRD_2014                        Panicum decompositum
# 16876    White_2020      Panicum decompositum var. decompositum
# 16877    White_2020           Panicum decompositum var. tenuius
# 16878    White_2020           Panicum decompositum var. tenuius
# 1014     Cheal_2017                             Panicum effusum
# 6094   Moore_2019_2                             Panicum effusum
# 6085   Moore_2019_2                             Panicum effusum
# 6086   Moore_2019_2                             Panicum effusum
# 6087   Moore_2019_2                             Panicum effusum
# 6088   Moore_2019_2                             Panicum effusum
# 6089   Moore_2019_2                             Panicum effusum
# 6090   Moore_2019_2                             Panicum effusum
# 6091   Moore_2019_2                             Panicum effusum
# 6092   Moore_2019_2                             Panicum effusum
# 6093   Moore_2019_2                             Panicum effusum
# 16880    White_2020                             Panicum effusum
# 6095   Moore_2019_2                             Panicum effusum
# 6097   Moore_2019_2                             Panicum effusum
# 6098   Moore_2019_2                             Panicum effusum
# 6099   Moore_2019_2                             Panicum effusum
# 6100   Moore_2019_2                             Panicum effusum
# 6101   Moore_2019_2                             Panicum effusum
# 6102   Moore_2019_2                             Panicum effusum
# 16882    White_2020                             Panicum effusum
# 6096   Moore_2019_2                             Panicum effusum
# 16883    White_2020                           Panicum laevinode
# 16893    White_2020                           Panicum laevinode
# 16884    White_2020                         Panicum larcomianum
# 16885    White_2020                            Panicum obseptum
# 9761    NSWFRD_2014                            Panicum obseptum
# 16889    White_2020                      Panicum queenslandicum
# 16887    White_2020      Panicum queenslandicum var. acuminatum
# 9762    NSWFRD_2014  Panicum queenslandicum var. queenslandicum
# 11500     Vesk_2004  Panicum queenslandicum var. queenslandicum
# 16888    White_2020  Panicum queenslandicum var. queenslandicum
# 16881    White_2020                              Panicum simile
# 9763    NSWFRD_2014                              Panicum simile
# 16890    White_2020                              Panicum simile
# 16892    White_2020                       Panicum subxerophilum
#
#       observation_id     trait_name                   trait_value unit  \
# 16891           5396  fire_response                   fire_killed
# 16875           5380  fire_response                     resprouts
# 16879           5384  fire_response                   fire_killed
# 9760            2138  fire_response                     resprouts
# 16876           5381  fire_response                   fire_killed
# 16877           5382  fire_response                   fire_killed
# 16878           5383  fire_response                   fire_killed
# 1014            1324  fire_response                     resprouts
# 6094            0561  fire_response           partial_resprouting
# 6085            0551  fire_response           partial_resprouting
# 6086            0552  fire_response           partial_resprouting
# 6087            0553  fire_response           partial_resprouting
# 6088            0554  fire_response           partial_resprouting
# 6089            0555  fire_response           partial_resprouting
# 6090            0556  fire_response                     resprouts
# 6091            0558  fire_response           partial_resprouting
# 6092            0559  fire_response           partial_resprouting
# 6093            0560  fire_response           partial_resprouting
# 16880           5385  fire_response                     resprouts
# 6095            0562  fire_response           partial_resprouting
# 6097            0565  fire_response           partial_resprouting
# 6098            0566  fire_response           partial_resprouting
# 6099            0567  fire_response           partial_resprouting
# 6100            0568  fire_response           partial_resprouting
# 6101            0569  fire_response           partial_resprouting
# 6102            0570  fire_response                     resprouts
# 16882           5387  fire_response                     resprouts
# 6096            0563  fire_response                     resprouts
# 16883           5388  fire_response                   fire_killed
# 16893           5398  fire_response                   fire_killed
# 16884           5389  fire_response                   fire_killed
# 16885           5390  fire_response                   fire_killed
# 9761            2139  fire_response                   fire_killed
# 16889           5394  fire_response                   fire_killed
# 16887           5392  fire_response                   fire_killed
# 9762            2140  fire_response                   fire_killed
# 11500            352  fire_response                   fire_killed
# 16888           5393  fire_response                   fire_killed
# 16881           5386  fire_response                     resprouts
# 9763            2141  fire_response                     resprouts
# 16890           5395  fire_response                     resprouts
# 16892           5397  fire_response  no_significant_fire_response
#
#       entity_type value_type basis_of_value replicates  ...  \
# 16891     species       mode   expert_score             ...
# 16875     species       mode   expert_score             ...
# 16879     species       mode   expert_score             ...
# 9760      species       mode   expert_score             ...
# 16876     species       mode   expert_score             ...
# 16877     species       mode   expert_score             ...
# 16878     species       mode   expert_score             ...
# 1014      species       mode   expert_score             ...
# 6094   individual        raw   expert_score             ...
# 6085   individual        raw   expert_score             ...
# 6086   individual        raw   expert_score             ...
# 6087   individual        raw   expert_score             ...
# 6088   individual        raw   expert_score             ...
# 6089   individual        raw   expert_score             ...
# 6090   individual        raw   expert_score             ...
# 6091   individual        raw   expert_score             ...
# 6092   individual        raw   expert_score             ...
# 6093   individual        raw   expert_score             ...
# 16880     species       mode   expert_score             ...
# 6095   individual        raw   expert_score             ...
# 6097   individual        raw   expert_score             ...
# 6098   individual        raw   expert_score             ...
# 6099   individual        raw   expert_score             ...
# 6100   individual        raw   expert_score             ...
# 6101   individual        raw   expert_score             ...
# 6102   individual        raw   expert_score             ...
# 16882     species       mode   expert_score             ...
# 6096   individual        raw   expert_score             ...
# 16883     species       mode   expert_score             ...
# 16893     species       mode   expert_score             ...
# 16884     species       mode   expert_score             ...
# 16885     species       mode   expert_score             ...
# 9761      species       mode   expert_score             ...
# 16889     species       mode   expert_score             ...
# 16887     species       mode   expert_score             ...
# 9762      species       mode   expert_score             ...
# 11500     species       mode   expert_score             ...
# 16888     species       mode   expert_score             ...
# 16881     species       mode   expert_score             ...
# 9763      species       mode   expert_score             ...
# 16890     species       mode   expert_score             ...
# 16892     species       mode   expert_score             ...
#
#                      binomial    genus   family  \
# 16891                          Panicum  Poaceae
# 16875          Panicum buncei  Panicum  Poaceae
# 16879    Panicum decompositum  Panicum  Poaceae
# 9760     Panicum decompositum  Panicum  Poaceae
# 16876    Panicum decompositum  Panicum  Poaceae
# 16877    Panicum decompositum  Panicum  Poaceae
# 16878    Panicum decompositum  Panicum  Poaceae
# 1014          Panicum effusum  Panicum  Poaceae
# 6094          Panicum effusum  Panicum  Poaceae
# 6085          Panicum effusum  Panicum  Poaceae
# 6086          Panicum effusum  Panicum  Poaceae
# 6087          Panicum effusum  Panicum  Poaceae
# 6088          Panicum effusum  Panicum  Poaceae
# 6089          Panicum effusum  Panicum  Poaceae
# 6090          Panicum effusum  Panicum  Poaceae
# 6091          Panicum effusum  Panicum  Poaceae
# 6092          Panicum effusum  Panicum  Poaceae
# 6093          Panicum effusum  Panicum  Poaceae
# 16880         Panicum effusum  Panicum  Poaceae
# 6095          Panicum effusum  Panicum  Poaceae
# 6097          Panicum effusum  Panicum  Poaceae
# 6098          Panicum effusum  Panicum  Poaceae
# 6099          Panicum effusum  Panicum  Poaceae
# 6100          Panicum effusum  Panicum  Poaceae
# 6101          Panicum effusum  Panicum  Poaceae
# 6102          Panicum effusum  Panicum  Poaceae
# 16882         Panicum effusum  Panicum  Poaceae
# 6096          Panicum effusum  Panicum  Poaceae
# 16883       Panicum laevinode  Panicum  Poaceae
# 16893       Panicum laevinode  Panicum  Poaceae
# 16884     Panicum larcomianum  Panicum  Poaceae
# 16885        Panicum obseptum  Panicum  Poaceae
# 9761         Panicum obseptum  Panicum  Poaceae
# 16889  Panicum queenslandicum  Panicum  Poaceae
# 16887  Panicum queenslandicum  Panicum  Poaceae
# 9762   Panicum queenslandicum  Panicum  Poaceae
# 11500  Panicum queenslandicum  Panicum  Poaceae
# 16888  Panicum queenslandicum  Panicum  Poaceae
# 16881          Panicum simile  Panicum  Poaceae
# 9763           Panicum simile  Panicum  Poaceae
# 16890          Panicum simile  Panicum  Poaceae
# 16892                          Panicum  Poaceae
#
#                        taxon_distribution     establishment_means  \
# 16891
# 16875          SA (naturalised), Qld, NSW  native and naturalised
# 16879           WA, NT, SA, Qld, NSW, Vic                  native
# 9760            WA, NT, SA, Qld, NSW, Vic                  native
# 16876                    NT, SA, Qld, Vic                  native
# 16877                             NT, Qld                  native
# 16878                             NT, Qld                  native
# 1014   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6094   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6085   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6086   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6087   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6088   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6089   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6090   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6091   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6092   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6093   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 16880  WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6095   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6097   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6098   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6099   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6100   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6101   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6102   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 16882  WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 6096   WA, NT, SA, Qld, NSW, NI, ACT, Vic                  native
# 16883           WA, NT, SA, Qld, NSW, Vic                  native
# 16893           WA, NT, SA, Qld, NSW, Vic                  native
# 16884                                 Qld                  native
# 16885                       Qld, NSW, Vic                  native
# 9761                        Qld, NSW, Vic                  native
# 16889                       Qld, NSW, Vic                  native
# 16887                            Qld, NSW                  native
# 9762                        Qld, NSW, Vic                  native
# 11500                       Qld, NSW, Vic                  native
# 16888                       Qld, NSW, Vic                  native
# 16881                   NT, Qld, NSW, Vic                  native
# 9763                    NT, Qld, NSW, Vic                  native
# 16890                   NT, Qld, NSW, Vic                  native
# 16892
#
#       taxonomic_status                                   scientific_name  \
# 16891         accepted                                        Panicum L.
# 16875         accepted                 Panicum buncei F.Muell. ex Benth.
# 16879         accepted                        Panicum decompositum R.Br.
# 9760          accepted                        Panicum decompositum R.Br.
# 16876         accepted      Panicum decompositum R.Br. var. decompositum
# 16877         accepted      Panicum decompositum var. tenuius F.M.Bailey
# 16878         accepted      Panicum decompositum var. tenuius F.M.Bailey
# 1014          accepted                             Panicum effusum R.Br.
# 6094          accepted                             Panicum effusum R.Br.
# 6085          accepted                             Panicum effusum R.Br.
# 6086          accepted                             Panicum effusum R.Br.
# 6087          accepted                             Panicum effusum R.Br.
# 6088          accepted                             Panicum effusum R.Br.
# 6089          accepted                             Panicum effusum R.Br.
# 6090          accepted                             Panicum effusum R.Br.
# 6091          accepted                             Panicum effusum R.Br.
# 6092          accepted                             Panicum effusum R.Br.
# 6093          accepted                             Panicum effusum R.Br.
# 16880         accepted                             Panicum effusum R.Br.
# 6095          accepted                             Panicum effusum R.Br.
# 6097          accepted                             Panicum effusum R.Br.
# 6098          accepted                             Panicum effusum R.Br.
# 6099          accepted                             Panicum effusum R.Br.
# 6100          accepted                             Panicum effusum R.Br.
# 6101          accepted                             Panicum effusum R.Br.
# 6102          accepted                             Panicum effusum R.Br.
# 16882         accepted                             Panicum effusum R.Br.
# 6096          accepted                             Panicum effusum R.Br.
# 16883         accepted                          Panicum laevinode Lindl.
# 16893         accepted                          Panicum laevinode Lindl.
# 16884         accepted                        Panicum larcomianum Hughes
# 16885         accepted                            Panicum obseptum Trin.
# 9761          accepted                            Panicum obseptum Trin.
# 16889         accepted                      Panicum queenslandicum Domin
# 16887         accepted    Panicum queenslandicum var. acuminatum Vickery
# 9762          accepted  Panicum queenslandicum Domin var. queenslandicum
# 11500         accepted  Panicum queenslandicum Domin var. queenslandicum
# 16888         accepted  Panicum queenslandicum Domin var. queenslandicum
# 16881         accepted                              Panicum simile Domin
# 9763          accepted                              Panicum simile Domin
# 16890         accepted                              Panicum simile Domin
# 16892         accepted                                        Panicum L.
#
#       scientific_name_authorship  \
# 16891                         L.
# 16875         F.Muell. ex Benth.
# 16879                      R.Br.
# 9760                       R.Br.
# 16876
# 16877                 F.M.Bailey
# 16878                 F.M.Bailey
# 1014                       R.Br.
# 6094                       R.Br.
# 6085                       R.Br.
# 6086                       R.Br.
# 6087                       R.Br.
# 6088                       R.Br.
# 6089                       R.Br.
# 6090                       R.Br.
# 6091                       R.Br.
# 6092                       R.Br.
# 6093                       R.Br.
# 16880                      R.Br.
# 6095                       R.Br.
# 6097                       R.Br.
# 6098                       R.Br.
# 6099                       R.Br.
# 6100                       R.Br.
# 6101                       R.Br.
# 6102                       R.Br.
# 16882                      R.Br.
# 6096                       R.Br.
# 16883                     Lindl.
# 16893                     Lindl.
# 16884                     Hughes
# 16885                      Trin.
# 9761                       Trin.
# 16889                      Domin
# 16887                    Vickery
# 9762
# 11500
# 16888
# 16881                      Domin
# 9763                       Domin
# 16890                      Domin
# 16892                         L.
#
#                                                 taxon_id  \
# 16891  https://id.biodiversity.org.au/taxon/apni/5129...
# 16875   https://id.biodiversity.org.au/node/apni/2905473
# 16879   https://id.biodiversity.org.au/node/apni/2897459
# 9760    https://id.biodiversity.org.au/node/apni/2897459
# 16876   https://id.biodiversity.org.au/node/apni/2915675
# 16877   https://id.biodiversity.org.au/node/apni/2921180
# 16878   https://id.biodiversity.org.au/node/apni/2921180
# 1014    https://id.biodiversity.org.au/node/apni/2907549
# 6094    https://id.biodiversity.org.au/node/apni/2907549
# 6085    https://id.biodiversity.org.au/node/apni/2907549
# 6086    https://id.biodiversity.org.au/node/apni/2907549
# 6087    https://id.biodiversity.org.au/node/apni/2907549
# 6088    https://id.biodiversity.org.au/node/apni/2907549
# 6089    https://id.biodiversity.org.au/node/apni/2907549
# 6090    https://id.biodiversity.org.au/node/apni/2907549
# 6091    https://id.biodiversity.org.au/node/apni/2907549
# 6092    https://id.biodiversity.org.au/node/apni/2907549
# 6093    https://id.biodiversity.org.au/node/apni/2907549
# 16880   https://id.biodiversity.org.au/node/apni/2907549
# 6095    https://id.biodiversity.org.au/node/apni/2907549
# 6097    https://id.biodiversity.org.au/node/apni/2907549
# 6098    https://id.biodiversity.org.au/node/apni/2907549
# 6099    https://id.biodiversity.org.au/node/apni/2907549
# 6100    https://id.biodiversity.org.au/node/apni/2907549
# 6101    https://id.biodiversity.org.au/node/apni/2907549
# 6102    https://id.biodiversity.org.au/node/apni/2907549
# 16882   https://id.biodiversity.org.au/node/apni/2907549
# 6096    https://id.biodiversity.org.au/node/apni/2907549
# 16883   https://id.biodiversity.org.au/node/apni/2915836
# 16893   https://id.biodiversity.org.au/node/apni/2915836
# 16884   https://id.biodiversity.org.au/node/apni/2920036
# 16885   https://id.biodiversity.org.au/node/apni/2915086
# 9761    https://id.biodiversity.org.au/node/apni/2915086
# 16889   https://id.biodiversity.org.au/node/apni/2918777
# 16887   https://id.biodiversity.org.au/node/apni/2907507
# 9762    https://id.biodiversity.org.au/node/apni/2905017
# 11500   https://id.biodiversity.org.au/node/apni/2905017
# 16888   https://id.biodiversity.org.au/node/apni/2905017
# 16881   https://id.biodiversity.org.au/node/apni/2903626
# 9763    https://id.biodiversity.org.au/node/apni/2903626
# 16890   https://id.biodiversity.org.au/node/apni/2903626
# 16892  https://id.biodiversity.org.au/taxon/apni/5129...
#
#                                    scientific_name_id
# 16891  https://id.biodiversity.org.au/name/apni/75784
# 16875  https://id.biodiversity.org.au/name/apni/94357
# 16879  https://id.biodiversity.org.au/name/apni/95008
# 9760   https://id.biodiversity.org.au/name/apni/95008
# 16876  https://id.biodiversity.org.au/name/apni/95044
# 16877  https://id.biodiversity.org.au/name/apni/95154
# 16878  https://id.biodiversity.org.au/name/apni/95154
# 1014   https://id.biodiversity.org.au/name/apni/95486
# 6094   https://id.biodiversity.org.au/name/apni/95486
# 6085   https://id.biodiversity.org.au/name/apni/95486
# 6086   https://id.biodiversity.org.au/name/apni/95486
# 6087   https://id.biodiversity.org.au/name/apni/95486
# 6088   https://id.biodiversity.org.au/name/apni/95486
# 6089   https://id.biodiversity.org.au/name/apni/95486
# 6090   https://id.biodiversity.org.au/name/apni/95486
# 6091   https://id.biodiversity.org.au/name/apni/95486
# 6092   https://id.biodiversity.org.au/name/apni/95486
# 6093   https://id.biodiversity.org.au/name/apni/95486
# 16880  https://id.biodiversity.org.au/name/apni/95486
# 6095   https://id.biodiversity.org.au/name/apni/95486
# 6097   https://id.biodiversity.org.au/name/apni/95486
# 6098   https://id.biodiversity.org.au/name/apni/95486
# 6099   https://id.biodiversity.org.au/name/apni/95486
# 6100   https://id.biodiversity.org.au/name/apni/95486
# 6101   https://id.biodiversity.org.au/name/apni/95486
# 6102   https://id.biodiversity.org.au/name/apni/95486
# 16882  https://id.biodiversity.org.au/name/apni/95486
# 6096   https://id.biodiversity.org.au/name/apni/95486
# 16883  https://id.biodiversity.org.au/name/apni/96812
# 16893  https://id.biodiversity.org.au/name/apni/96812
# 16884  https://id.biodiversity.org.au/name/apni/96864
# 16885  https://id.biodiversity.org.au/name/apni/97426
# 9761   https://id.biodiversity.org.au/name/apni/97426
# 16889  https://id.biodiversity.org.au/name/apni/98084
# 16887  https://id.biodiversity.org.au/name/apni/98105
# 9762   https://id.biodiversity.org.au/name/apni/98126
# 11500  https://id.biodiversity.org.au/name/apni/98126
# 16888  https://id.biodiversity.org.au/name/apni/98126
# 16881  https://id.biodiversity.org.au/name/apni/98625
# 9763   https://id.biodiversity.org.au/name/apni/98625
# 16890  https://id.biodiversity.org.au/name/apni/98625
# 16892  https://id.biodiversity.org.au/name/apni/75784
#
# [42 rows x 53 columns]

# %% [markdown]
# ### Clean-up data
#  - Remove rows with `trait_value` = "unknown" - treat as if no entry existed
#  - Remove rows with `taxon_name` containing `sp.` desingations - we don't want higher taxon matches for now.
#  - See a list of distinct values for the trait value column

# %%
print("before:", len(df.index))
df = df[df.trait_value != "unknown"]
df = df[~df['taxon_name'].str.contains(r'\s+sp\.')]
print("after:", len(df.index))
print("unique traits:", df['trait_value'].unique())
# Out:
# before: 13632
# after: 13243
# unique traits: ['c3' 'c4' 'cam' 'c3-c4' 'c4-cam' 'c3-cam' 'facultative_cam' 'c3 cam'
#  'c3 c4']

# %% [markdown]
# Extract only the few columns of interest and rename column names for importing into lists app.

# %%
# df2 = df[['taxon_name','binomial','taxon_rank','trait_name','trait_value','location']].copy()
df2 = df.rename(columns={'taxon_name':'taxon','trait_name': 'traitName', 'trait_value': 'traitValue'})

df2.head(80)
# Out:
#            dataset_id                        taxon observation_id  \
# 9826       White_2020         Abrodictyum caudatum           4818
# 6886       White_2020         Abrodictyum caudatum           1747
# 5192       White_2020         Abrotanella nivigena           0004
# 4911     Schmidt_2003            Abrus precatorius           0005
# 5207       White_2020                     Abutilon           0020
# ...               ...                          ...            ...
# 5234       White_2020              Acacia bivenosa           0047
# 5233       White_2020  Acacia bivenosa subsp. wayi           0046
# 5236       White_2020             Acacia boormanii           0049
# 1     Cunningham_1999          Acacia brachybotrya            006
# 5237       White_2020          Acacia brachybotrya           0050
#
#                    traitName traitValue unit entity_type value_type  \
# 9826  photosynthetic_pathway         c3          species       mode
# 6886  photosynthetic_pathway         c3          species       mode
# 5192  photosynthetic_pathway         c3          species       mode
# 4911  photosynthetic_pathway         c3          species       mode
# 5207  photosynthetic_pathway         c3          species       mode
# ...                      ...        ...  ...         ...        ...
# 5234  photosynthetic_pathway         c3          species       mode
# 5233  photosynthetic_pathway         c3          species       mode
# 5236  photosynthetic_pathway         c3          species       mode
# 1     photosynthetic_pathway         c3          species       mode
# 5237  photosynthetic_pathway         c3          species       mode
#
#      basis_of_value replicates  ...              binomial        genus  \
# 9826   expert_score             ...  Abrodictyum caudatum  Abrodictyum
# 6886   expert_score             ...  Abrodictyum caudatum  Abrodictyum
# 5192   expert_score             ...  Abrotanella nivigena  Abrotanella
# 4911   expert_score             ...     Abrus precatorius        Abrus
# 5207   expert_score             ...                           Abutilon
# ...             ...        ...  ...                   ...          ...
# 5234   expert_score             ...       Acacia bivenosa       Acacia
# 5233   expert_score             ...                             Acacia
# 5236   expert_score             ...      Acacia boormanii       Acacia
# 1      expert_score             ...   Acacia brachybotrya       Acacia
# 5237   expert_score             ...   Acacia brachybotrya       Acacia
#
#                 family           taxon_distribution     establishment_means  \
# 9826  Hymenophyllaceae                Qld, NSW, Vic                  native
# 6886  Hymenophyllaceae                Qld, NSW, Vic                  native
# 5192        Asteraceae                     NSW, Vic                  native
# 4911          Fabaceae             WA, NT, Qld, NSW                  native
# 5207         Malvaceae
# ...                ...                          ...                     ...
# 5234          Fabaceae                  WA, NT, Qld                  native
# 5233          Fabaceae
# 5236          Fabaceae  NSW, ACT (naturalised), Vic  native and naturalised
# 1             Fabaceae                 SA, NSW, Vic                  native
# 5237          Fabaceae                 SA, NSW, Vic                  native
#
#      taxonomic_status                                   scientific_name  \
# 9826         accepted  Abrodictyum caudatum (Brack.) Ebihara & K.Iwats.
# 6886         accepted  Abrodictyum caudatum (Brack.) Ebihara & K.Iwats.
# 5192         accepted          Abrotanella nivigena (F.Muell.) F.Muell.
# 4911         accepted                              Abrus precatorius L.
# 5207         accepted                                    Abutilon Mill.
# ...               ...                                               ...
# 5234         accepted                               Acacia bivenosa DC.
# 5233         accepted                                      Acacia Mill.
# 5236         accepted                           Acacia boormanii Maiden
# 1            accepted                        Acacia brachybotrya Benth.
# 5237         accepted                        Acacia brachybotrya Benth.
#
#        scientific_name_authorship  \
# 9826  (Brack.) Ebihara & K.Iwats.
# 6886  (Brack.) Ebihara & K.Iwats.
# 5192          (F.Muell.) F.Muell.
# 4911                           L.
# 5207                        Mill.
# ...                           ...
# 5234                          DC.
# 5233                        Mill.
# 5236                       Maiden
# 1                          Benth.
# 5237                       Benth.
#
#                                                taxon_id  \
# 9826   https://id.biodiversity.org.au/node/apni/7402200
# 6886   https://id.biodiversity.org.au/node/apni/7402200
# 5192   https://id.biodiversity.org.au/node/apni/2900512
# 4911   https://id.biodiversity.org.au/node/apni/2919311
# 5207  https://id.biodiversity.org.au/taxon/apni/5143...
# ...                                                 ...
# 5234   https://id.biodiversity.org.au/node/apni/2912987
# 5233  https://id.biodiversity.org.au/taxon/apni/5147...
# 5236  https://id.biodiversity.org.au/taxon/apni/5143...
# 1      https://id.biodiversity.org.au/node/apni/2892012
# 5237   https://id.biodiversity.org.au/node/apni/2892012
#
#                                    scientific_name_id
# 9826  https://id.biodiversity.org.au/name/apni/241954
# 6886  https://id.biodiversity.org.au/name/apni/241954
# 5192   https://id.biodiversity.org.au/name/apni/56120
# 4911   https://id.biodiversity.org.au/name/apni/56149
# 5207   https://id.biodiversity.org.au/name/apni/56205
# ...                                               ...
# 5234   https://id.biodiversity.org.au/name/apni/59491
# 5233   https://id.biodiversity.org.au/name/apni/56859
# 5236   https://id.biodiversity.org.au/name/apni/59572
# 1      https://id.biodiversity.org.au/name/apni/59600
# 5237   https://id.biodiversity.org.au/name/apni/59600
#
# [80 rows x 53 columns]

# %% [markdown]
# Transform data for taxa that have multiple entries with different values in `traitValue` column - combining all values into a pipe-delimited column.
# See https://www.statology.org/pandas-combine-rows-with-same-column-value/

# %% [markdown]
# Debugging section - delete if no longer required

# %%
df_tmp = df2.loc[df2['traitValue'] == "fire_killed resprouts"]
print(df_tmp[['taxon','traitValue']].to_string(index=False)) 
# df_Solanum = df[df['taxon'] == 'Solanum']
# print(df_Solanum.head())
contain_values = df2[df2['taxon'].str.contains(r'\s+sp\.')]
print (len(contain_values))
# Out:
# Empty DataFrame
# Columns: [taxon, traitValue]
# Index: []
# 0

# %%
# cleanup data for `traitValue` with values that are already mulit-valued (shouldn't be, data should have 1-to-1 ratio of rows to traits
# #     col1  col2
# 0  a,b,c     1
# 1  d,e,f     2
# df.assign(col1 = df.col1.str.split(',')).explode('col1', ignore_index=True)
print("before", df2['traitValue'].unique(), len(df2.index))

df3 = df2.assign(traitValue = df2.traitValue.str.split()).explode('traitValue', ignore_index=True).reset_index(drop=True).ffill()
# df4 = df.assign(traitValue=df['traitValue'].str.split()).explode('traitValue')
print("after 1", df3['traitValue'].unique(), len(df3.index))
# print("after 2", df4['traitValue'].unique(), len(df4.index))
# df.head(5)
# Out:
# before ['c3' 'c4' 'cam' 'c3-c4' 'c4-cam' 'c3-cam' 'facultative_cam' 'c3 cam'
#  'c3 c4'] 13243
# after 1 ['c3' 'c4' 'cam' 'c3-c4' 'c4-cam' 'c3-cam' 'facultative_cam'] 13248

# %%
#df['traitValue'] = df['traitValue'].str.replace('fire_killed resprouts', 'fire_killed|resprouts')
#     col1  col2
# 0  a,b,c     1
# 1  d,e,f     2
# df.assign(col1 = df.col1.str.split(',')).explode('col1', ignore_index=True)
# df.assign(traitValue = df.traitValue.str.split(' ')).explode('traitValue', ignore_index=True)
# This groupBy combines rows with the same `taxon` value and adds the `traitValue` for each to a set, 
# then converts to a list and sorts it, and then joins with `|` to a string value. 
# This is to prevernt seeing values of `fire_killed|resprouts` and `resprouts|fire_killed` in the index (effectively the same)
df4 = df3.groupby(['taxon','traitName'])['traitValue'].agg(lambda x: sorted(list(set(x)))).apply('|'.join).reset_index()
# df2 = df.groupby(['taxon','traitName'])['traitValue'].agg(lambda x: set(x)).apply('|'.join).reset_index()
# df2['traitValue'] = df['traitValue'].str.replace('unknown', '')
grouped_rows = len(df4.index)
print("Total rows =",len(df.index))
print("Grouped rows =",grouped_rows)
print(df4['traitValue'].unique())
df4.head(50)
# df3.head(20)
# Out:
# Total rows = 13243
# Grouped rows = 8547
# ['c3' 'c3|c4' 'c3|cam' 'c4' 'cam' 'c3|c3-c4' 'c4|c4-cam' 'c4|cam'
#  'c3-cam|cam' 'c3-cam' 'cam|facultative_cam' 'c3|cam|facultative_cam'
#  'c3-c4' 'c3-c4|cam']
#                                       taxon               traitName traitValue
# 0                      Abrodictyum caudatum  photosynthetic_pathway         c3
# 1                      Abrotanella nivigena  photosynthetic_pathway         c3
# 2                         Abrus precatorius  photosynthetic_pathway         c3
# 3                                  Abutilon  photosynthetic_pathway         c3
# 4                     Abutilon calliphyllum  photosynthetic_pathway         c3
# 5                          Abutilon fraseri  photosynthetic_pathway         c3
# 6      Abutilon fraseri subsp. diplotrichum  photosynthetic_pathway         c3
# 7           Abutilon fraseri subsp. fraseri  photosynthetic_pathway         c3
# 8                       Abutilon halophilum  photosynthetic_pathway         c3
# 9                           Abutilon hannii  photosynthetic_pathway         c3
# 10                    Abutilon leucopetalum  photosynthetic_pathway         c3
# 11                     Abutilon malvifolium  photosynthetic_pathway         c3
# 12                       Abutilon otocarpum  photosynthetic_pathway         c3
# 13                       Abutilon oxycarpum  photosynthetic_pathway         c3
# 14           Abutilon oxycarpum f. acutatum  photosynthetic_pathway         c3
# 15          Abutilon oxycarpum var. incanum  photosynthetic_pathway         c3
# 16        Abutilon oxycarpum var. oxycarpum  photosynthetic_pathway         c3
# 17    Abutilon oxycarpum var. subsagittatum  photosynthetic_pathway         c3
# 18                                   Acacia  photosynthetic_pathway         c3
# 19                         Acacia X grayana  photosynthetic_pathway         c3
# 20  Acacia acanthoclada subsp. acanthoclada  photosynthetic_pathway         c3
# 21                          Acacia acinacea  photosynthetic_pathway         c3
# 22                     Acacia aculeatissima  photosynthetic_pathway         c3
# 23                         Acacia acuminata  photosynthetic_pathway         c3
# 24        Acacia acuminata subsp. burkittii  photosynthetic_pathway         c3
# 25                             Acacia adoxa  photosynthetic_pathway         c3
# 26                         Acacia alleniana  photosynthetic_pathway         c3
# 27                            Acacia alpina  photosynthetic_pathway         c3
# 28                            Acacia amoena  photosynthetic_pathway         c3
# 29                         Acacia ampliceps  photosynthetic_pathway         c3
# 30                            Acacia anceps  photosynthetic_pathway         c3
# 31                     Acacia ancistrocarpa  photosynthetic_pathway         c3
# 32   Acacia ancistrophylla var. lissophylla  photosynthetic_pathway         c3
# 33                            Acacia aneura  photosynthetic_pathway         c3
# 34                Acacia aneura var. aneura  photosynthetic_pathway         c3
# 35             Acacia aneura var. latifolia  photosynthetic_pathway         c3
# 36                 Acacia aneura var. major  photosynthetic_pathway         c3
# 37                           Acacia aprepta  photosynthetic_pathway         c3
# 38                         Acacia aptaneura  photosynthetic_pathway         c3
# 39                          Acacia araneosa  photosynthetic_pathway         c3
# 40                      Acacia argyrophylla  photosynthetic_pathway         c3
# 41                            Acacia aspera  photosynthetic_pathway         c3
# 42              Acacia aspera subsp. aspera  photosynthetic_pathway         c3
# 43           Acacia aspera subsp. parviceps  photosynthetic_pathway         c3
# 44                       Acacia asperulacea  photosynthetic_pathway         c3
# 45                         Acacia assimilis  photosynthetic_pathway         c3
# 46                        Acacia atkinsiana  photosynthetic_pathway         c3
# 47                    Acacia auriculiformis  photosynthetic_pathway         c3
# 48                         Acacia ausfeldii  photosynthetic_pathway         c3
# 49                         Acacia ayersiana  photosynthetic_pathway         c3

# %%
df4.to_csv(f"/data/arga-data/aus_traits_{trait_name}.csv", index=False)

# %%
json_records = df4.to_dict('tight')
# print("json_records:", list(json_records.items())[:10])
print("json_records:",json_records['data'][:40])
# Out:
# json_records: [['Abrodictyum caudatum', 'photosynthetic_pathway', 'c3'], ['Abrotanella nivigena', 'photosynthetic_pathway', 'c3'], ['Abrus precatorius', 'photosynthetic_pathway', 'c3'], ['Abutilon', 'photosynthetic_pathway', 'c3'], ['Abutilon calliphyllum', 'photosynthetic_pathway', 'c3'], ['Abutilon fraseri', 'photosynthetic_pathway', 'c3'], ['Abutilon fraseri subsp. diplotrichum', 'photosynthetic_pathway', 'c3'], ['Abutilon fraseri subsp. fraseri', 'photosynthetic_pathway', 'c3'], ['Abutilon halophilum', 'photosynthetic_pathway', 'c3'], ['Abutilon hannii', 'photosynthetic_pathway', 'c3'], ['Abutilon leucopetalum', 'photosynthetic_pathway', 'c3'], ['Abutilon malvifolium', 'photosynthetic_pathway', 'c3'], ['Abutilon otocarpum', 'photosynthetic_pathway', 'c3'], ['Abutilon oxycarpum', 'photosynthetic_pathway', 'c3'], ['Abutilon oxycarpum f. acutatum', 'photosynthetic_pathway', 'c3'], ['Abutilon oxycarpum var. incanum', 'photosynthetic_pathway', 'c3'], ['Abutilon oxycarpum var. oxycarpum', 'photosynthetic_pathway', 'c3'], ['Abutilon oxycarpum var. subsagittatum', 'photosynthetic_pathway', 'c3'], ['Acacia', 'photosynthetic_pathway', 'c3'], ['Acacia X grayana', 'photosynthetic_pathway', 'c3'], ['Acacia acanthoclada subsp. acanthoclada', 'photosynthetic_pathway', 'c3'], ['Acacia acinacea', 'photosynthetic_pathway', 'c3'], ['Acacia aculeatissima', 'photosynthetic_pathway', 'c3'], ['Acacia acuminata', 'photosynthetic_pathway', 'c3'], ['Acacia acuminata subsp. burkittii', 'photosynthetic_pathway', 'c3'], ['Acacia adoxa', 'photosynthetic_pathway', 'c3'], ['Acacia alleniana', 'photosynthetic_pathway', 'c3'], ['Acacia alpina', 'photosynthetic_pathway', 'c3'], ['Acacia amoena', 'photosynthetic_pathway', 'c3'], ['Acacia ampliceps', 'photosynthetic_pathway', 'c3'], ['Acacia anceps', 'photosynthetic_pathway', 'c3'], ['Acacia ancistrocarpa', 'photosynthetic_pathway', 'c3'], ['Acacia ancistrophylla var. lissophylla', 'photosynthetic_pathway', 'c3'], ['Acacia aneura', 'photosynthetic_pathway', 'c3'], ['Acacia aneura var. aneura', 'photosynthetic_pathway', 'c3'], ['Acacia aneura var. latifolia', 'photosynthetic_pathway', 'c3'], ['Acacia aneura var. major', 'photosynthetic_pathway', 'c3'], ['Acacia aprepta', 'photosynthetic_pathway', 'c3'], ['Acacia aptaneura', 'photosynthetic_pathway', 'c3'], ['Acacia araneosa', 'photosynthetic_pathway', 'c3']]

# %% [markdown]
# Output from json_records:
# ```json
#  [
#   [
#     "Abelmoschus ficulneus",
#     "fire_response",
#     "fire_killed"
#   ],
#   [
#     "Abelmoschus moschatus",
#     "fire_response",
#     "resprouts"
#   ],
#   [
#     "Abrodictyum caudatum",
#     "fire_response",
#     "fire_killed"
#   ],
#   [
#     "Abrotanella",
#     "fire_response",
#     "resprouts"
#   ]
# ]
# ```
#
# Munge data into required format (see below)
#
# ```json
# [
#   {
#     "itemName": "item1",
#     "kvpValues": [
#       {
#         "key": "key1",
#         "value": "value1"
#       },
#       {
#         "key": "key2",
#         "value": "value2"
#       }
#     ]
#   },
#   {
#     "itemName": "item2",
#     "kvpValues": [
#       {
#         "key": "key3",
#         "value": "value3"
#       },
#       {
#         "key": "key4",
#         "value": "value4"
#       }
#     ]
#   }
# ]
# ```

# %%
list_items = []

#for taxon_record in json_records['data']:
limit = 1000000 # lower for debugging
for count, taxon_record in enumerate(json_records['data']):
    this_item = {
        "itemName": taxon_record[0],
        "kvpValues": [
            {"key": "traitName", "value": taxon_record[1]},
            {"key": "traitValue", "value": taxon_record[2]}
        ]
    }
    list_items.append(this_item)
    if count >= limit: break
    
print("list_items", list_items[:30])
# Out:
# list_items [{'itemName': 'Abrodictyum caudatum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abrotanella nivigena', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abrus precatorius', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon calliphyllum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon fraseri', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon fraseri subsp. diplotrichum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon fraseri subsp. fraseri', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon halophilum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon hannii', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon leucopetalum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon malvifolium', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon otocarpum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon oxycarpum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon oxycarpum f. acutatum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon oxycarpum var. incanum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon oxycarpum var. oxycarpum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Abutilon oxycarpum var. subsagittatum', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia X grayana', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia acanthoclada subsp. acanthoclada', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia acinacea', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia aculeatissima', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia acuminata', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia acuminata subsp. burkittii', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia adoxa', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic_pathway'}, {'key': 'traitValue', 'value': 'c3'}]}, {'itemName': 'Acacia alleniana', 'kvpValues': [{'key': 'traitName', 'value': 'photosynthetic ...

# %% [markdown]
# ### Push data to lists.ala.org.au (or lists-test.ala.org.au).
#
# See API docs: https://docs.test.ala.org.au/openapi/index.html?urls.primaryName=specieslist#/Lists/Add%20or%20replace%20a%20species%20list
#
# POST body data example:
#
# CURL example: `curl "api_endpoint_here" -H "Authorization: Bearer {access_token}"`
#
# Note that the `decouple` module can either read a `.env` file at the repository root or via environment variables (e.g. via Airflow)
#
# POST body example:
#
# ```json
# {
#   "listName": "list1",
#   "listType": "TEST",
#   "listItems": [
#     {
#       "itemName": "item1",
#       "kvpValues": [
#         {
#           "key": "key1",
#           "value": "value1"
#         },
#         {
#           "key": "key2",
#           "value": "value2"
#         }
#       ]
#     }
#   ]
# }
# ```

# %%
import requests
import json
import sys, os
sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'code'))
from access_token import create_token
import decouple

config = decouple.AutoConfig(' ') # this is a hack for Jupyter due to running in a sandbox


# ACCESS_TOKEN = config('ACCESS_TOKEN')
access_token = create_token()
ALA_USER_ID = config('ALA_USER_ID', default=13)
# REFRESH_TOKEN = config('REFRESH_TOKEN')
# print("Checking tokens:",access_token)
# print("Checking userID:",ALA_USER_ID)

ALA_API_BASE_URL = config('ALA_API_BASE_URL', default="https://api.ala.org.au")
# alaUserId = config('ALA_USER_ID') # userID for owner of the list or anyone with admin role
dataResourceId = trait_dr_id # trait_drs[trait_name] 
lists_url = f"{ALA_API_BASE_URL}/specieslist/ws/speciesListPost/{dataResourceId}"
headers = {"Content-Type":"application/json", "Authorization": f"Bearer {access_token}", "X-ALA-userId": f"{ALA_USER_ID}"}

payload = {
    "listName": f"AusTraits {trait_name} trait list",
    "listItems": list_items,
}
json_body = json.dumps(payload)
print("url", lists_url)
# print("body", json_body)
r = requests.post(lists_url, data=json_body, headers=headers)
# print("connection data",lists_url,headers)

if r.ok:
    # data = r.json()
    print("POST success:", r.text, "| status code:", r.status_code)
else:
    print("Unable to POST data. ", r.status_code, r.text)
# print("actual request headers", r.request.headers)
# Out:
# url https://api.test.ala.org.au/specieslist/ws/speciesListPost/dr18707
# Unable to POST data.  504 {"message": "Endpoint request timed out"}

# %%
print("number of taxa:", len(list_items))
# Out:
# number of taxa: 8547
